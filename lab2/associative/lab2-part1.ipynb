# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

transactions = [
    ['a', 'b', 'c'],
    ['b', 'd'],
    ['b', 'a', 'd', 'c'],
    ['e', 'd'],
    ['a', 'b', 'c', 'd'],
    ['f'],
]

from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

min_support = 0.5
min_confidence = 0.7

# %%
frequent_itemsets = apriori(df, min_support, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)

print("Frequent Itemsets:")
print(frequent_itemsets)

print("\nAssociation Rules:")
print(rules[['antecedents', 'consequents', 'confidence']])
# Out:
# Frequent Itemsets:
#     support   itemsets
# 0  0.500000        (a)
# 1  0.666667        (b)
# 2  0.500000        (c)
# 3  0.666667        (d)
# 4  0.500000     (a, b)
# 5  0.500000     (c, a)
# 6  0.500000     (c, b)
# 7  0.500000     (d, b)
# 8  0.500000  (c, a, b)
#
# Association Rules:
#    antecedents consequents  confidence
# 0          (a)         (b)        1.00
# 1          (b)         (a)        0.75
# 2          (c)         (a)        1.00
# 3          (a)         (c)        1.00
# 4          (c)         (b)        1.00
# 5          (b)         (c)        0.75
# 6          (d)         (b)        0.75
# 7          (b)         (d)        0.75
# 8       (c, a)         (b)        1.00
# 9       (c, b)         (a)        1.00
# 10      (a, b)         (c)        1.00
# 11         (c)      (a, b)        1.00
# 12         (a)      (c, b)        1.00
# 13         (b)      (c, a)        0.75

# %%
from apriori import apriori
from apriori import generate_rules

frequent_itemsets, support_data = apriori(transactions, min_support)
rules = generate_rules(frequent_itemsets, support_data, min_confidence)

print("Frequent Itemsets:")
for itemset in frequent_itemsets:
    print(set(itemset), "=>", f"support: {support_data[itemset]:.2f}")

print("\n\nAssociation Rules:")
for antecedent, consequent, support, confidence in rules:
    print(f"{set(antecedent)} => {set(consequent)} (support: {support:.2f}, confidence: {confidence:.2f})")
# Out:
# Frequent Itemsets:
# {'c'} => support: 0.50
# {'a'} => support: 0.50
# {'b'} => support: 0.67
# {'d'} => support: 0.67
# {'c', 'a'} => support: 0.50
# {'c', 'b'} => support: 0.50
# {'d', 'b'} => support: 0.50
# {'a', 'b'} => support: 0.50
# {'c', 'a', 'b'} => support: 0.50
#
#
# Association Rules:
# {'c'} => {'a'} (support: 0.50, confidence: 1.00)
# {'a'} => {'c'} (support: 0.50, confidence: 1.00)
# {'c'} => {'b'} (support: 0.50, confidence: 1.00)
# {'b'} => {'c'} (support: 0.50, confidence: 0.75)
# {'d'} => {'b'} (support: 0.50, confidence: 0.75)
# {'b'} => {'d'} (support: 0.50, confidence: 0.75)
# {'a'} => {'b'} (support: 0.50, confidence: 1.00)
# {'b'} => {'a'} (support: 0.50, confidence: 0.75)
# {'c'} => {'a', 'b'} (support: 0.50, confidence: 1.00)
# {'a'} => {'c', 'b'} (support: 0.50, confidence: 1.00)
# {'b'} => {'c', 'a'} (support: 0.50, confidence: 0.75)
# {'c', 'a'} => {'b'} (support: 0.50, confidence: 1.00)
# {'c', 'b'} => {'a'} (support: 0.50, confidence: 1.00)
# {'a', 'b'} => {'c'} (support: 0.50, confidence: 1.00)
# Frequent Itemsets:
# {'c'} => support: 0.50
# {'a'} => support: 0.50
# {'b'} => support: 0.67
# {'d'} => support: 0.67
# {'c', 'a'} => support: 0.50
# {'c', 'b'} => support: 0.50
# {'d', 'b'} => support: 0.50
# {'a', 'b'} => support: 0.50
# {'c', 'a', 'b'} => support: 0.50
#
#
# Association Rules:
# {'c'} => {'a'} (support: 0.50, confidence: 1.00)
# {'a'} => {'c'} (support: 0.50, confidence: 1.00)
# {'c'} => {'b'} (support: 0.50, confidence: 1.00)
# {'b'} => {'c'} (support: 0.50, confidence: 0.75)
# {'d'} => {'b'} (support: 0.50, confidence: 0.75)
# {'b'} => {'d'} (support: 0.50, confidence: 0.75)
# {'a'} => {'b'} (support: 0.50, confidence: 1.00)
# {'b'} => {'a'} (support: 0.50, confidence: 0.75)
# {'c'} => {'a', 'b'} (support: 0.50, confidence: 1.00)
# {'a'} => {'c', 'b'} (support: 0.50, confidence: 1.00)
# {'b'} => {'c', 'a'} (support: 0.50, confidence: 0.75)
# {'c', 'a'} => {'b'} (support: 0.50, confidence: 1.00)
# {'c', 'b'} => {'a'} (support: 0.50, confidence: 1.00)
# {'a', 'b'} => {'c'} (support: 0.50, confidence: 1.00)

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori as mlxtend_apriori
from mlxtend.frequent_patterns import association_rules as mlxtend_rules

def assert_apriori_equal(transactions, min_support=0.5, min_confidence=0.7):
    te = TransactionEncoder()
    te_ary = te.fit(transactions).transform(transactions)
    df = pd.DataFrame(te_ary, columns=te.columns_)

    mlxtend_frequent = mlxtend_apriori(df, min_support=min_support, use_colnames=True)
    mlxtend_rule_df = mlxtend_rules(mlxtend_frequent, metric="confidence", min_threshold=min_confidence)

    mlxtend_itemsets = {frozenset(x): round(s, 5) for x, s in zip(mlxtend_frequent['itemsets'], mlxtend_frequent['support'])}
    mlxtend_rules_set = set()
    for _, row in mlxtend_rule_df.iterrows():
        mlxtend_rules_set.add((
            frozenset(row['antecedents']),
            frozenset(row['consequents']),
            round(row['support'], 5),
            round(row['confidence'], 5)
        ))

    custom_itemsets, custom_support_data = apriori(transactions, min_support)
    custom_itemsets_dict = {itemset: round(support, 5) for itemset, support in custom_support_data.items()}

    custom_rules = generate_rules(custom_itemsets, custom_support_data, min_confidence)
    custom_rules_set = set(
        (frozenset(ant), frozenset(con), round(sup, 5), round(conf, 5))
        for ant, con, sup, conf in custom_rules
    )

    assert mlxtend_itemsets == custom_itemsets_dict, "Frequent itemsets do not match!"
    assert mlxtend_rules_set == custom_rules_set, "Association rules do not match!"

    print("✅ Custom and mlxtend Apriori implementations produce the same results.")

# %%
assert_apriori_equal(transactions, min_support=0.6, min_confidence=0.7)
# Out:
# ✅ Custom and mlxtend Apriori implementations produce the same results.

# %%
import pandas as pd

df_tmp = pd.read_csv("./groceries.csv", header=None, on_bad_lines='skip')
# print(df1)

tx_list = df_tmp.apply(
    lambda row: [item for item in row if pd.notnull(item) and item != ''],
    axis=1
)
print(tx_list)

te = TransactionEncoder()
te_ary = te.fit(tx_list).transform(tx_list)
df = pd.DataFrame(te_ary, columns=te.columns_)
print(te.columns_)
df.shape
# Out:
# 0       [citrus fruit, semi-finished bread, margarine,...
# 1                        [tropical fruit, yogurt, coffee]
# 2                                            [whole milk]
# 3        [pip fruit, yogurt, cream cheese , meat spreads]
# 4       [other vegetables, whole milk, condensed milk,...
#                               ...
# 6101                   [yogurt, long life bakery product]
# 6102                    [pork, frozen vegetables, pastry]
# 6103    [ice cream, long life bakery product, specialt...
# 6104                                  [cooking chocolate]
# 6105    [semi-finished bread, bottled water, soda, bot...
# Length: 6106, dtype: object
# ['Instant food products', 'UHT-milk', 'abrasive cleaner', 'artif. sweetener', 'baby cosmetics', 'bags', 'baking powder', 'bathroom cleaner', 'beef', 'berries', 'beverages', 'bottled beer', 'bottled water', 'brandy', 'brown bread', 'butter', 'butter milk', 'cake bar', 'candles', 'candy', 'canned beer', 'canned fish', 'canned fruit', 'canned vegetables', 'cat food', 'cereals', 'chewing gum', 'chicken', 'chocolate', 'chocolate marshmallow', 'citrus fruit', 'cleaner', 'cling film/bags', 'cocoa drinks', 'coffee', 'condensed milk', 'cooking chocolate', 'cookware', 'cream', 'cream cheese ', 'curd', 'curd cheese', 'decalcifier', 'dental care', 'dessert', 'detergent', 'dish cleaner', 'dishes', 'dog food', 'domestic eggs', 'female sanitary products', 'finished products', 'fish', 'flour', 'flower (seeds)', 'flower soil/fertilizer', 'frankfurter', 'frozen chicken', 'frozen dessert', 'frozen fish', 'frozen fruits', 'frozen meals', 'frozen potato products', 'frozen vegetables', 'fruit/vegetable juice', 'grapes', 'hair spray', 'ham', 'hamburger meat', 'hard cheese', 'herbs', 'honey', 'house keeping products', 'hygiene articles', 'ice cream', 'instant coffee', 'jam', 'ketchup', 'kitchen towels', 'kitchen utensil', 'light bulbs', 'liqueur', 'liquor', 'liquor (appetizer)', 'liver loaf', 'long life bakery product', 'make up remover', 'male cosmetics', 'margarine', 'mayonnaise', 'meat', 'meat spreads', 'misc. beverages', 'mustard', 'napkins', 'newspapers', 'nut snack', 'nuts/prunes', 'oil', 'onions', 'organic products', 'organic sausage', 'other vegetables', 'packaged fruit/vegetables', 'pasta', 'pastry', 'pet care', 'photo/film', 'pickled vegetables', 'pip fruit', 'popcorn', 'pork', 'pot plants', 'potato products', 'processed cheese', 'prosecco', 'pudding powder', 'ready soups', 'red/blush wine', 'rice', 'roll products ', 'rolls/buns', 'root vegetables', 'rubbing alcohol', 'rum', 'salad dressing', 'salt', 'salty snack', 'sauces', 'sausage', 'seasonal products', 'semi-finished bread', 'shopping bags', 'skin care', 'sliced cheese', 'snack products', 'soap', 'soda', 'soft cheese', 'softener', 'soups', 'sparkling wine', 'specialty bar', 'specialty cheese', 'specialty chocolate', 'specialty fat', 'spices', 'spread cheese', 'sugar', 'sweet spreads', 'syrup', 'tea', 'tidbits', 'toilet cleaner', 'tropical fruit', 'turkey', 'vinegar', 'waffles', 'whipped/sour cream', 'whisky', 'white bread', 'white wine', 'whole milk', 'yogurt', 'zwieback']
# (6106, 165)

# %%
frequent_itemsets = mlxtend_apriori(df, min_support=0.001, use_colnames=True)
rules = mlxtend_rules(frequent_itemsets, metric="confidence", min_threshold=0.3)

print("Frequent Itemsets:")
print(frequent_itemsets)

print("\nAssociation Rules:")
print(rules[['antecedents', 'consequents', 'confidence']])
# Out:
# Frequent Itemsets:
#       support                                         itemsets
# 0    0.003112                          (Instant food products)
# 1    0.015558                                       (UHT-milk)
# 2    0.001310                               (artif. sweetener)
# 3    0.004913                                  (baking powder)
# 4    0.001146                               (bathroom cleaner)
# ..        ...                                              ...
# 511  0.001146     (rolls/buns, fruit/vegetable juice, sausage)
# 512  0.001146       (rolls/buns, other vegetables, whole milk)
# 513  0.001310  (whole milk, other vegetables, root vegetables)
# 514  0.001146             (whole milk, other vegetables, soda)
# 515  0.003439                      (rolls/buns, sausage, soda)
#
# [516 rows x 2 columns]
#
# Association Rules:
#                             antecedents         consequents  confidence
# 0                              (liquor)      (bottled beer)    0.562500
# 1                         (canned fish)        (rolls/buns)    0.323529
# 2                      (condensed milk)            (coffee)    0.352941
# 3                    (specialty cheese)  (other vegetables)    0.333333
# 4                       (spread cheese)        (rolls/buns)    0.379310
# 5              (red/blush wine, liquor)      (bottled beer)    0.928571
# 6        (red/blush wine, bottled beer)            (liquor)    0.722222
# 7                (liquor, bottled beer)    (red/blush wine)    0.361111
# 8           (pip fruit, tropical fruit)      (citrus fruit)    0.304348
# 9             (pip fruit, citrus fruit)    (tropical fruit)    0.388889
# 10       (tropical fruit, citrus fruit)         (pip fruit)    0.304348
# 11  (rolls/buns, fruit/vegetable juice)           (sausage)    0.318182
# 12     (sausage, fruit/vegetable juice)        (rolls/buns)    0.700000
# 13                      (sausage, soda)        (rolls/buns)    0.500000

# %%
from apriori import apriori
from apriori import generate_rules

frequent_itemsets, support_data = apriori(tx_list, min_support=0.001)
rules = generate_rules(frequent_itemsets, support_data, min_confidence=0.3)

print("Frequent Itemsets:")
for itemset in frequent_itemsets:
    print(set(itemset), "=>", f"support: {support_data[itemset]:.5f}")

print("\n\nAssociation Rules:")
for antecedent, consequent, support, confidence in rules:
    print(f"{set(antecedent)} => {set(consequent)} (support: {support:.5f}, confidence: {confidence:.5f})")
# Out:
# Frequent Itemsets:
# {'popcorn'} => support: 0.00213
# {'light bulbs'} => support: 0.00229
# {'soups'} => support: 0.00147
# {'domestic eggs'} => support: 0.02096
# {'sliced cheese'} => support: 0.00573
# {'rice'} => support: 0.00115
# {'frozen meals'} => support: 0.01572
# {'margarine'} => support: 0.02195
# {'chicken'} => support: 0.01785
# {'curd'} => support: 0.02031
# {'yogurt'} => support: 0.06289
# {'specialty bar'} => support: 0.02145
# {'liquor (appetizer)'} => support: 0.00540
# {'pickled vegetables'} => support: 0.00360
# {'zwieback'} => support: 0.00409
# {'misc. beverages'} => support: 0.01916
# {'waffles'} => support: 0.01818
# {'prosecco'} => support: 0.00164
# {'male cosmetics'} => support: 0.00295
# {'whipped/sour cream'} => support: 0.02653
# {'specialty chocolate'} => support: 0.02211
# {'sausage'} => support: 0.04815
# {'cream cheese '} => support: 0.01458
# {'tropical fruit'} => support: 0.03980
# {'pet care'} => support: 0.00704
# {'potato products'} => support: 0.00115
# {'flower soil/fertilizer'} => support: 0.00213
# {'ice cream'} => support: 0.01900
# {'cake bar'} => support: 0.00540
# {'frozen dessert'} => support: 0.00426
# {'long life bakery product'} => support: 0.01638
# {'soap'} => support: 0.00147
# {'canned fruit'} => support: 0.00131
# {'skin care'} => support: 0.00131
# {'beef'} => support: 0.02391
# {'sauces'} => support: 0.00213
# {'canned fish'} => support: 0.00557
# {'spread cheese'} => support: 0.00475
# {'specialty cheese'} => support: 0.00393
# {'pip fruit'} => support: 0.03095
# {'ketchup'} => support: 0.00147
# {'hamburger meat'} => support: 0.01228
# {'cooking chocolate'} => support: 0.00147
# {'napkins'} => support: 0.01949
# {'rolls/buns'} => support: 0.12611
# {'dental care'} => support: 0.00197
# {'root vegetables'} => support: 0.03718
# {'pastry'} => support: 0.05044
# {'cookware'} => support: 0.00197
# {'sparkling wine'} => support: 0.00360
# {'white wine'} => support: 0.01654
# {'berries'} => support: 0.01228
# {'chocolate marshmallow'} => support: 0.00442
# {'shopping bags'} => support: 0.04848
# {'vinegar'} => support: 0.00180
# {'candy'} => support: 0.01572
# {'syrup'} => support: 0.00147
# {'soda'} => support: 0.12660
# {'pasta'} => support: 0.00508
# {'processed cheese'} => support: 0.00491
# {'oil'} => support: 0.01032
# {'seasonal products'} => support: 0.00835
# {'house keeping products'} => support: 0.00344
# {'detergent'} => support: 0.00753
# {'hard cheese'} => support: 0.00868
# {'meat spreads'} => support: 0.00213
# {'snack products'} => support: 0.00229
# {'cereals'} => support: 0.00213
# {'curd cheese'} => support: 0.00262
# {'meat'} => support: 0.01065
# {'rum'} => support: 0.00295
# {'instant coffee'} => support: 0.00393
# {'dessert'} => support: 0.01572
# {'butter milk'} => support: 0.01228
# {'canned beer'} => support: 0.08221
# {'brandy'} => support: 0.00262
# {'frozen potato products'} => support: 0.00344
# {'artif. sweetener'} => support: 0.00131
# {'condensed milk'} => support: 0.00557
# {'spices'} => support: 0.00197
# {'specialty fat'} => support: 0.00147
# {'cling film/bags'} => support: 0.00377
# {'liquor'} => support: 0.01048
# {'hygiene articles'} => support: 0.01245
# {'nut snack'} => support: 0.00180
# {'pork'} => support: 0.02620
# {'red/blush wine'} => support: 0.01343
# {'flour'} => support: 0.00377
# {'frankfurter'} => support: 0.02882
# {'brown bread'} => support: 0.03194
# {'nuts/prunes'} => support: 0.00180
# {'bottled beer'} => support: 0.06649
# {'salty snack'} => support: 0.01867
# {'canned vegetables'} => support: 0.00377
# {'salt'} => support: 0.00344
# {'beverages'} => support: 0.01834
# {'pot plants'} => support: 0.01065
# {'white bread'} => support: 0.01654
# {'newspapers'} => support: 0.04848
# {'herbs'} => support: 0.00459
# {'chewing gum'} => support: 0.01556
# {'bathroom cleaner'} => support: 0.00115
# {'whole milk'} => support: 0.14068
# {'mustard'} => support: 0.00328
# {'UHT-milk'} => support: 0.01556
# {'female sanitary products'} => support: 0.00328
# {'coffee'} => support: 0.03374
# {'ham'} => support: 0.00868
# {'mayonnaise'} => support: 0.00197
# {'softener'} => support: 0.00197
# {'butter'} => support: 0.01867
# {'sugar'} => support: 0.01261
# {'packaged fruit/vegetables'} => support: 0.00622
# {'frozen vegetables'} => support: 0.01703
# {'onions'} => support: 0.01081
# {'Instant food products'} => support: 0.00311
# {'chocolate'} => support: 0.02571
# {'fish'} => support: 0.00213
# {'fruit/vegetable juice'} => support: 0.03046
# {'turkey'} => support: 0.00213
# {'dish cleaner'} => support: 0.00426
# {'roll products '} => support: 0.00278
# {'sweet spreads'} => support: 0.00262
# {'cleaner'} => support: 0.00180
# {'liver loaf'} => support: 0.00229
# {'candles'} => support: 0.00426
# {'bottled water'} => support: 0.06649
# {'dishes'} => support: 0.00868
# {'semi-finished bread'} => support: 0.00819
# {'finished products'} => support: 0.00426
# {'jam'} => support: 0.00147
# {'dog food'} => support: 0.00328
# {'soft cheese'} => support: 0.00622
# {'photo/film'} => support: 0.00983
# {'frozen fish'} => support: 0.00491
# {'baking powder'} => support: 0.00491
# {'other vegetables'} => support: 0.08696
# {'flower (seeds)'} => support: 0.00426
# {'cat food'} => support: 0.00901
# {'grapes'} => support: 0.00901
# {'citrus fruit'} => support: 0.03406
# {'rolls/buns', 'chewing gum'} => support: 0.00246
# {'chewing gum', 'bottled water'} => support: 0.00131
# {'sausage', 'coffee'} => support: 0.00164
# {'whipped/sour cream', 'curd'} => support: 0.00131
# {'whole milk', 'soft cheese'} => support: 0.00131
# {'rolls/buns', 'soda'} => support: 0.01785
# {'sausage', 'white wine'} => support: 0.00131
# {'pip fruit', 'pastry'} => support: 0.00115
# {'pork', 'root vegetables'} => support: 0.00197
# {'pip fruit', 'canned beer'} => support: 0.00115
# {'shopping bags', 'bottled water'} => support: 0.00131
# {'yogurt', 'beverages'} => support: 0.00164
# {'soda', 'curd'} => support: 0.00147
# {'rolls/buns', 'whipped/sour cream'} => support: 0.00131
# {'rolls/buns', 'shopping bags'} => support: 0.00491
# {'brown bread', 'soda'} => support: 0.00180
# {'other vegetables', 'fruit/vegetable juice'} => support: 0.00213
# {'whole milk', 'frozen vegetables'} => support: 0.00360
# {'rolls/buns', 'canned beer'} => support: 0.00557
# {'other vegetables', 'tropical fruit'} => support: 0.00491
# {'bottled beer', 'frankfurter'} => support: 0.00147
# {'brown bread', 'canned beer'} => support: 0.00147
# {'pork', 'frozen vegetables'} => support: 0.00131
# {'dessert', 'bottled water'} => support: 0.00115
# {'yogurt', 'whipped/sour cream'} => support: 0.00311
# {'pip fruit', 'frankfurter'} => support: 0.00115
# {'whole milk', 'onions'} => support: 0.00180
# {'sausage', 'pastry'} => support: 0.00246
# {'other vegetables', 'domestic eggs'} => support: 0.00180
# {'whole milk', 'bottled beer'} => support: 0.00557
# {'bottled beer', 'bottled water'} => support: 0.00639
# {'bottled water', 'soda'} => support: 0.01081
# {'margarine', 'brown bread'} => support: 0.00131
# {'rolls/buns', 'bottled water'} => support: 0.00639
# {'other vegetables', 'newspapers'} => support: 0.00278
# {'white wine', 'shopping bags'} => support: 0.00197
# {'rolls/buns', 'fruit/vegetable juice'} => support: 0.00360
# {'misc. beverages', 'bottled water'} => support: 0.00180
# {'yogurt', 'UHT-milk'} => support: 0.00115
# {'pastry', 'soda'} => support: 0.00786
# {'rolls/buns', 'frankfurter'} => support: 0.00819
# {'rolls/buns', 'pastry'} => support: 0.00622
# {'other vegetables', 'chewing gum'} => support: 0.00147
# {'pastry', 'frozen vegetables'} => support: 0.00115
# {'specialty chocolate', 'bottled water'} => support: 0.00131
# {'whipped/sour cream', 'domestic eggs'} => support: 0.00147
# {'pastry', 'bottled water'} => support: 0.00197
# {'newspapers', 'bottled water'} => support: 0.00311
# {'whole milk', 'whipped/sour cream'} => support: 0.00491
# {'whole milk', 'curd'} => support: 0.00540
# {'margarine', 'other vegetables'} => support: 0.00229
# {'citrus fruit', 'root vegetables'} => support: 0.00213
# {'whole milk', 'pastry'} => support: 0.00884
# {'chocolate', 'pastry'} => support: 0.00147
# {'brown bread', 'root vegetables'} => support: 0.00131
# {'tropical fruit', 'bottled water'} => support: 0.00246
# {'specialty bar', 'bottled water'} => support: 0.00115
# {'shopping bags', 'chicken'} => support: 0.00115
# {'waffles', 'chocolate'} => support: 0.00115
# {'shopping bags', 'root vegetables'} => support: 0.00213
# {'beef', 'bottled beer'} => support: 0.00115
# {'whole milk', 'specialty chocolate'} => support: 0.00147
# {'yogurt', 'napkins'} => support: 0.00131
# {'whole milk', 'beverages'} => support: 0.00246
# {'whole milk', 'chicken'} => support: 0.00229
# {'bottled beer', 'fruit/vegetable juice'} => support: 0.00131
# {'specialty bar', 'pastry'} => support: 0.00115
# {'newspapers', 'citrus fruit'} => support: 0.00147
# {'margarine', 'pastry'} => support: 0.00115
# {'bottled beer', 'pastry'} => support: 0.00115
# {'rolls/buns', 'newspapers'} => support: 0.00606
# {'rolls/buns', 'butter milk'} => support: 0.00164
# {'brown bread', 'frankfurter'} => support: 0.00115
# {'beef', 'whole milk'} => support: 0.00393
# {'coffee', 'bottled water'} => support: 0.00147
# {'chocolate', 'shopping bags'} => support: 0.00131
# {'rolls/buns', 'coffee'} => support: 0.00295
# {'liquor (appetizer)', 'bottled beer'} => support: 0.00147
# {'rolls/buns', 'soft cheese'} => support: 0.00164
# {'rolls/buns', 'beverages'} => support: 0.00246
# {'misc. beverages', 'bottled beer'} => support: 0.00115
# {'bottled beer', 'butter'} => support: 0.00115
# {'onions', 'root vegetables'} => support: 0.00115
# {'whole milk', 'sugar'} => support: 0.00278
# {'napkins', 'soda'} => support: 0.00131
# {'rolls/buns', 'bottled beer'} => support: 0.00622
# {'other vegetables', 'curd'} => support: 0.00115
# {'brown bread', 'bottled beer'} => support: 0.00147
# {'whole milk', 'hard cheese'} => support: 0.00180
# {'yogurt', 'whole milk'} => support: 0.00835
# {'rolls/buns', 'pork'} => support: 0.00131
# {'brown bread', 'other vegetables'} => support: 0.00213
# {'rolls/buns', 'ham'} => support: 0.00164
# {'other vegetables', 'butter'} => support: 0.00180
# {'white bread', 'soda'} => support: 0.00164
# {'yogurt', 'domestic eggs'} => support: 0.00115
# {'specialty chocolate', 'soda'} => support: 0.00328
# {'rolls/buns', 'whole milk'} => support: 0.01539
# {'rolls/buns', 'specialty chocolate'} => support: 0.00213
# {'coffee', 'sugar'} => support: 0.00131
# {'yogurt', 'fruit/vegetable juice'} => support: 0.00213
# {'yogurt', 'root vegetables'} => support: 0.00328
# {'shopping bags', 'tropical fruit'} => support: 0.00131
# {'other vegetables', 'bottled beer'} => support: 0.00344
# {'hamburger meat', 'soda'} => support: 0.00115
# {'brown bread', 'fruit/vegetable juice'} => support: 0.00131
# {'whole milk', 'root vegetables'} => support: 0.00786
# {'citrus fruit', 'curd'} => support: 0.00131
# {'rolls/buns', 'root vegetables'} => support: 0.00197
# {'margarine', 'sausage'} => support: 0.00115
# {'fruit/vegetable juice', 'dessert'} => support: 0.00147
# {'whole milk', 'soda'} => support: 0.00884
# {'long life bakery product', 'fruit/vegetable juice'} => support: 0.00147
# {'margarine', 'bottled beer'} => support: 0.00147
# {'liquor', 'bottled beer'} => support: 0.00590
# {'coffee', 'UHT-milk'} => support: 0.00131
# {'chocolate', 'tropical fruit'} => support: 0.00115
# {'red/blush wine', 'canned beer'} => support: 0.00213
# {'other vegetables', 'cream cheese '} => support: 0.00147
# {'whole milk', 'butter milk'} => support: 0.00213
# {'brown bread', 'whole milk'} => support: 0.00639
# {'yogurt', 'coffee'} => support: 0.00147
# {'rolls/buns', 'long life bakery product'} => support: 0.00115
# {'white bread', 'newspapers'} => support: 0.00164
# {'bottled beer', 'root vegetables'} => support: 0.00115
# {'other vegetables', 'ham'} => support: 0.00115
# {'yogurt', 'butter milk'} => support: 0.00164
# {'fruit/vegetable juice', 'soda'} => support: 0.00409
# {'beef', 'other vegetables'} => support: 0.00475
# {'whole milk', 'semi-finished bread'} => support: 0.00131
# {'beef', 'citrus fruit'} => support: 0.00147
# {'brown bread', 'tropical fruit'} => support: 0.00164
# {'rolls/buns', 'chocolate'} => support: 0.00246
# {'rolls/buns', 'citrus fruit'} => support: 0.00278
# {'other vegetables', 'shopping bags'} => support: 0.00328
# {'yogurt', 'pip fruit'} => support: 0.00213
# {'sausage', 'bottled water'} => support: 0.00164
# {'yogurt', 'bottled water'} => support: 0.00393
# {'other vegetables', 'canned beer'} => support: 0.00180
# {'whole milk', 'newspapers'} => support: 0.00802
# {'cream cheese ', 'soda'} => support: 0.00115
# {'beverages', 'pastry'} => support: 0.00147
# {'UHT-milk', 'soda'} => support: 0.00213
# {'long life bakery product', 'shopping bags'} => support: 0.00115
# {'frozen meals', 'shopping bags'} => support: 0.00164
# {'other vegetables', 'salty snack'} => support: 0.00115
# {'citrus fruit', 'bottled water'} => support: 0.00164
# {'chewing gum', 'soda'} => support: 0.00278
# {'whole milk', 'ice cream'} => support: 0.00131
# {'frankfurter', 'root vegetables'} => support: 0.00115
# {'yogurt', 'frozen vegetables'} => support: 0.00147
# {'whole milk', 'hamburger meat'} => support: 0.00115
# {'bottled beer', 'soda'} => support: 0.00770
# {'pork', 'shopping bags'} => support: 0.00180
# {'sausage', 'bottled beer'} => support: 0.00311
# {'whipped/sour cream', 'berries'} => support: 0.00262
# {'brown bread', 'shopping bags'} => support: 0.00131
# {'yogurt', 'rolls/buns'} => support: 0.00704
# {'waffles', 'whole milk'} => support: 0.00131
# {'other vegetables', 'oil'} => support: 0.00131
# {'other vegetables', 'root vegetables'} => support: 0.00753
# {'whole milk', 'coffee'} => support: 0.00459
# {'sausage', 'whole milk'} => support: 0.00606
# {'waffles', 'newspapers'} => support: 0.00115
# {'yogurt', 'beef'} => support: 0.00164
# {'other vegetables', 'berries'} => support: 0.00131
# {'butter', 'soda'} => support: 0.00131
# {'rolls/buns', 'candy'} => support: 0.00131
# {'rolls/buns', 'sugar'} => support: 0.00147
# {'whole milk', 'tropical fruit'} => support: 0.00671
# {'bottled water', 'root vegetables'} => support: 0.00131
# {'beef', 'whipped/sour cream'} => support: 0.00115
# {'chicken', 'citrus fruit'} => support: 0.00115
# {'rolls/buns', 'meat'} => support: 0.00180
# {'rolls/buns', 'domestic eggs'} => support: 0.00311
# {'whole milk', 'pip fruit'} => support: 0.00475
# {'waffles', 'soda'} => support: 0.00295
# {'beverages', 'bottled water'} => support: 0.00131
# {'white bread', 'bottled beer'} => support: 0.00115
# {'other vegetables', 'hamburger meat'} => support: 0.00262
# {'soda', 'root vegetables'} => support: 0.00213
# {'newspapers', 'tropical fruit'} => support: 0.00246
# {'sausage', 'rolls/buns'} => support: 0.01343
# {'whole milk', 'citrus fruit'} => support: 0.00475
# {'other vegetables', 'frankfurter'} => support: 0.00197
# {'sausage', 'soda'} => support: 0.00688
# {'specialty bar', 'soda'} => support: 0.00442
# {'rolls/buns', 'cream cheese '} => support: 0.00311
# {'other vegetables', 'frozen vegetables'} => support: 0.00180
# {'pork', 'bottled water'} => support: 0.00131
# {'whole milk', 'bottled water'} => support: 0.00884
# {'domestic eggs', 'root vegetables'} => support: 0.00131
# {'yogurt', 'sausage'} => support: 0.00295
# {'other vegetables', 'coffee'} => support: 0.00147
# {'beef', 'newspapers'} => support: 0.00115
# {'long life bakery product', 'pastry'} => support: 0.00164
# {'meat', 'whole milk'} => support: 0.00213
# {'domestic eggs', 'soda'} => support: 0.00180
# {'chocolate', 'soda'} => support: 0.00393
# {'shopping bags', 'citrus fruit'} => support: 0.00131
# {'brown bread', 'pastry'} => support: 0.00180
# {'bottled water', 'curd'} => support: 0.00115
# {'shopping bags', 'frankfurter'} => support: 0.00164
# {'napkins', 'bottled water'} => support: 0.00180
# {'red/blush wine', 'other vegetables'} => support: 0.00131
# {'margarine', 'soda'} => support: 0.00164
# {'brown bread', 'bottled water'} => support: 0.00213
# {'shopping bags', 'soda'} => support: 0.00671
# {'yogurt', 'berries'} => support: 0.00278
# {'white wine', 'bottled water'} => support: 0.00344
# {'whole milk', 'domestic eggs'} => support: 0.00409
# {'other vegetables', 'butter milk'} => support: 0.00197
# {'whole milk', 'chewing gum'} => support: 0.00180
# {'frozen meals', 'whole milk'} => support: 0.00197
# {'yogurt', 'white wine'} => support: 0.00131
# {'canned beer', 'soda'} => support: 0.00508
# {'beef', 'rolls/buns'} => support: 0.00229
# {'red/blush wine', 'bottled beer'} => support: 0.00295
# {'red/blush wine', 'liquor'} => support: 0.00229
# {'other vegetables', 'citrus fruit'} => support: 0.00606
# {'other vegetables', 'chocolate'} => support: 0.00164
# {'rolls/buns', 'spread cheese'} => support: 0.00180
# {'yogurt', 'newspapers'} => support: 0.00295
# {'frankfurter', 'citrus fruit'} => support: 0.00115
# {'coffee', 'soda'} => support: 0.00180
# {'shopping bags', 'canned beer'} => support: 0.00442
# {'whole milk', 'specialty bar'} => support: 0.00147
# {'beverages', 'soda'} => support: 0.00164
# {'other vegetables', 'whipped/sour cream'} => support: 0.00393
# {'whipped/sour cream', 'root vegetables'} => support: 0.00164
# {'other vegetables', 'bottled water'} => support: 0.00246
# {'rolls/buns', 'brown bread'} => support: 0.00442
# {'other vegetables', 'pastry'} => support: 0.00197
# {'other vegetables', 'onions'} => support: 0.00180
# {'pip fruit', 'soda'} => support: 0.00262
# {'pork', 'whole milk'} => support: 0.00360
# {'yogurt', 'chocolate'} => support: 0.00164
# {'pastry', 'canned beer'} => support: 0.00180
# {'margarine', 'bottled water'} => support: 0.00131
# {'rolls/buns', 'canned fish'} => support: 0.00180
# {'ice cream', 'soda'} => support: 0.00278
# {'bottled water', 'canned beer'} => support: 0.00360
# {'sausage', 'newspapers'} => support: 0.00164
# {'newspapers', 'curd'} => support: 0.00115
# {'whole milk', 'chocolate'} => support: 0.00213
# {'shopping bags', 'seasonal products'} => support: 0.00131
# {'margarine', 'yogurt'} => support: 0.00180
# {'tropical fruit', 'soda'} => support: 0.00213
# {'sausage', 'fruit/vegetable juice'} => support: 0.00164
# {'candy', 'soda'} => support: 0.00164
# {'tropical fruit', 'citrus fruit'} => support: 0.00377
# {'misc. beverages', 'soda'} => support: 0.00246
# {'whole milk', 'butter'} => support: 0.00409
# {'meat', 'soda'} => support: 0.00131
# {'pork', 'other vegetables'} => support: 0.00426
# {'waffles', 'rolls/buns'} => support: 0.00115
# {'whole milk', 'long life bakery product'} => support: 0.00197
# {'sausage', 'citrus fruit'} => support: 0.00131
# {'sausage', 'root vegetables'} => support: 0.00147
# {'fruit/vegetable juice', 'bottled water'} => support: 0.00229
# {'whole milk', 'fruit/vegetable juice'} => support: 0.00360
# {'yogurt', 'citrus fruit'} => support: 0.00311
# {'yogurt', 'soda'} => support: 0.00328
# {'white bread', 'shopping bags'} => support: 0.00115
# {'yogurt', 'bottled beer'} => support: 0.00115
# {'other vegetables', 'white bread'} => support: 0.00311
# {'sausage', 'brown bread'} => support: 0.00213
# {'whole milk', 'detergent'} => support: 0.00115
# {'other vegetables', 'napkins'} => support: 0.00180
# {'rolls/buns', 'specialty bar'} => support: 0.00262
# {'yogurt', 'other vegetables'} => support: 0.00606
# {'rolls/buns', 'tropical fruit'} => support: 0.00426
# {'white wine', 'bottled beer'} => support: 0.00147
# {'whole milk', 'dessert'} => support: 0.00344
# {'dessert', 'soda'} => support: 0.00213
# {'coffee', 'shopping bags'} => support: 0.00229
# {'sausage', 'chocolate'} => support: 0.00131
# {'other vegetables', 'chicken'} => support: 0.00311
# {'sausage', 'canned beer'} => support: 0.00213
# {'salty snack', 'canned beer'} => support: 0.00115
# {'fruit/vegetable juice', 'newspapers'} => support: 0.00213
# {'domestic eggs', 'citrus fruit'} => support: 0.00115
# {'yogurt', 'tropical fruit'} => support: 0.00377
# {'whipped/sour cream', 'newspapers'} => support: 0.00131
# {'misc. beverages', 'shopping bags'} => support: 0.00115
# {'whole milk', 'cat food'} => support: 0.00115
# {'whole milk', 'pot plants'} => support: 0.00147
# {'soda', 'cake bar'} => support: 0.00131
# {'bottled beer', 'newspapers'} => support: 0.00197
# {'rolls/buns', 'red/blush wine'} => support: 0.00164
# {'coffee', 'pip fruit'} => support: 0.00115
# {'pastry', 'root vegetables'} => support: 0.00164
# {'pork', 'soda'} => support: 0.00295
# {'margarine', 'whole milk'} => support: 0.00491
# {'rolls/buns', 'pip fruit'} => support: 0.00164
# {'whole milk', 'shopping bags'} => support: 0.00393
# {'whole milk', 'ham'} => support: 0.00213
# {'shopping bags', 'fruit/vegetable juice'} => support: 0.00147
# {'pip fruit', 'tropical fruit'} => support: 0.00377
# {'margarine', 'beef'} => support: 0.00164
# {'yogurt', 'cream cheese '} => support: 0.00131
# {'pip fruit', 'bottled water'} => support: 0.00197
# {'newspapers', 'canned beer'} => support: 0.00213
# {'rolls/buns', 'chicken'} => support: 0.00131
# {'pastry', 'newspapers'} => support: 0.00246
# {'whole milk', 'salty snack'} => support: 0.00164
# {'beef', 'root vegetables'} => support: 0.00360
# {'sausage', 'tropical fruit'} => support: 0.00115
# {'whole milk', 'candy'} => support: 0.00115
# {'margarine', 'rolls/buns'} => support: 0.00262
# {'whole milk', 'other vegetables'} => support: 0.01458
# {'sausage', 'other vegetables'} => support: 0.00311
# {'cream cheese ', 'butter milk'} => support: 0.00115
# {'pork', 'pastry'} => support: 0.00164
# {'coffee', 'condensed milk'} => support: 0.00197
# {'frankfurter', 'soda'} => support: 0.00328
# {'pip fruit', 'citrus fruit'} => support: 0.00295
# {'frozen meals', 'soda'} => support: 0.00262
# {'pastry', 'tropical fruit'} => support: 0.00180
# {'frozen meals', 'frozen vegetables'} => support: 0.00115
# {'yogurt', 'pastry'} => support: 0.00246
# {'white bread', 'root vegetables'} => support: 0.00131
# {'yogurt', 'canned beer'} => support: 0.00131
# {'whipped/sour cream', 'tropical fruit'} => support: 0.00115
# {'brown bread', 'newspapers'} => support: 0.00115
# {'meat', 'other vegetables'} => support: 0.00180
# {'yogurt', 'shopping bags'} => support: 0.00246
# {'whole milk', 'cream cheese '} => support: 0.00328
# {'UHT-milk', 'bottled water'} => support: 0.00197
# {'liquor', 'soda'} => support: 0.00131
# {'waffles', 'pastry'} => support: 0.00131
# {'chicken', 'root vegetables'} => support: 0.00131
# {'red/blush wine', 'newspapers'} => support: 0.00131
# {'whole milk', 'canned beer'} => support: 0.00278
# {'shopping bags', 'bottled beer'} => support: 0.00246
# {'processed cheese', 'soda'} => support: 0.00131
# {'citrus fruit', 'soda'} => support: 0.00147
# {'pastry', 'domestic eggs'} => support: 0.00147
# {'salty snack', 'soda'} => support: 0.00197
# {'pastry', 'citrus fruit'} => support: 0.00147
# {'yogurt', 'waffles'} => support: 0.00115
# {'rolls/buns', 'butter'} => support: 0.00229
# {'rolls/buns', 'other vegetables'} => support: 0.00802
# {'rolls/buns', 'UHT-milk'} => support: 0.00164
# {'margarine', 'frankfurter'} => support: 0.00131
# {'other vegetables', 'grapes'} => support: 0.00131
# {'shopping bags', 'pastry'} => support: 0.00197
# {'chocolate', 'canned beer'} => support: 0.00115
# {'long life bakery product', 'soda'} => support: 0.00131
# {'sausage', 'shopping bags'} => support: 0.00295
# {'frankfurter', 'newspapers'} => support: 0.00131
# {'yogurt', 'brown bread'} => support: 0.00197
# {'whole milk', 'frankfurter'} => support: 0.00409
# {'other vegetables', 'dessert'} => support: 0.00147
# {'yogurt', 'specialty bar'} => support: 0.00131
# {'sausage', 'sliced cheese'} => support: 0.00115
# {'other vegetables', 'pip fruit'} => support: 0.00377
# {'hygiene articles', 'napkins'} => support: 0.00131
# {'yogurt', 'curd'} => support: 0.00295
# {'other vegetables', 'specialty cheese'} => support: 0.00131
# {'whole milk', 'white bread'} => support: 0.00344
# {'whole milk', 'napkins'} => support: 0.00197
# {'other vegetables', 'soda'} => support: 0.00671
# {'margarine', 'root vegetables'} => support: 0.00131
# {'coffee', 'pastry'} => support: 0.00131
# {'newspapers', 'soda'} => support: 0.00278
# {'shopping bags', 'newspapers'} => support: 0.00164
# {'bottled beer', 'soda', 'bottled water'} => support: 0.00147
# {'pip fruit', 'tropical fruit', 'citrus fruit'} => support: 0.00115
# {'red/blush wine', 'liquor', 'bottled beer'} => support: 0.00213
# {'whole milk', 'other vegetables', 'root vegetables'} => support: 0.00131
# {'rolls/buns', 'other vegetables', 'whole milk'} => support: 0.00115
# {'rolls/buns', 'fruit/vegetable juice', 'sausage'} => support: 0.00115
# {'whole milk', 'other vegetables', 'soda'} => support: 0.00115
# {'rolls/buns', 'sausage', 'soda'} => support: 0.00344
#
#
# Association Rules:
# {'liquor'} => {'bottled beer'} (support: 0.00590, confidence: 0.56250)
# {'spread cheese'} => {'rolls/buns'} (support: 0.00180, confidence: 0.37931)
# {'canned fish'} => {'rolls/buns'} (support: 0.00180, confidence: 0.32353)
# {'condensed milk'} => {'coffee'} (support: 0.00197, confidence: 0.35294)
# {'specialty cheese'} => {'other vegetables'} (support: 0.00131, confidence: 0.33333)
# {'pip fruit', 'tropical fruit'} => {'citrus fruit'} (support: 0.00115, confidence: 0.30435)
# {'pip fruit', 'citrus fruit'} => {'tropical fruit'} (support: 0.00115, confidence: 0.38889)
# {'tropical fruit', 'citrus fruit'} => {'pip fruit'} (support: 0.00115, confidence: 0.30435)
# {'red/blush wine', 'liquor'} => {'bottled beer'} (support: 0.00213, confidence: 0.92857)
# {'red/blush wine', 'bottled beer'} => {'liquor'} (support: 0.00213, confidence: 0.72222)
# {'liquor', 'bottled beer'} => {'red/blush wine'} (support: 0.00213, confidence: 0.36111)
# {'rolls/buns', 'fruit/vegetable juice'} => {'sausage'} (support: 0.00115, confidence: 0.31818)
# {'sausage', 'fruit/vegetable juice'} => {'rolls/buns'} (support: 0.00115, confidence: 0.70000)
# {'sausage', 'soda'} => {'rolls/buns'} (support: 0.00344, confidence: 0.50000)

# %%
assert_apriori_equal(tx_list, min_support=0.001, min_confidence=0.3)
# Out:
# ✅ Custom and mlxtend Apriori implementations produce the same results.
